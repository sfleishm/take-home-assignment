# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_time_series_confirmed = pd.read_csv("csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")
df_time_series_confirmed.head()
# Out:
#   Province/State Country/Region      Lat      Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN       Thailand  15.0000  101.0000        2        3        5
# 1            NaN          Japan  36.0000  138.0000        2        1        2
# 2            NaN      Singapore   1.2833  103.8333        0        1        3
# 3            NaN          Nepal  28.1667   84.2500        0        0        0
# 4            NaN       Malaysia   2.5000  112.5000        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/4/20  3/5/20  3/6/20  3/7/20  3/8/20  \
# 0        7        8        8  ...      43      47      48      50      50
# 1        2        4        4  ...     331     360     420     461     502
# 2        3        4        5  ...     110     117     130     138     150
# 3        1        1        1  ...       1       1       1       1       1
# 4        3        4        4  ...      50      50      83      93      99
#
#    3/9/20  3/10/20  3/11/20  3/12/20  3/13/20
# 0      50       53       59       70       75
# 1     511      581      639      639      701
# 2     150      160      178      178      200
# 3       1        1        1        1        1
# 4     117      129      149      149      197
#
# [5 rows x 56 columns]

# %%
df_time_series_confirmed_china = df_time_series_confirmed.loc[df_time_series_confirmed['Country/Region'] == 'China']
df_time_series_confirmed_china.head()
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 156          Hubei          China  30.9756  112.2707      444      444
# 160      Guangdong          China  23.3417  113.4244       26       32
# 161          Henan          China  33.8820  113.6140        5        5
# 162       Zhejiang          China  29.1832  120.0934       10       27
# 163          Hunan          China  27.6104  111.7088        4        9
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/4/20  3/5/20  3/6/20  3/7/20  \
# 156      549      761     1058     1423  ...   67332   67466   67592   67666
# 160       53       78      111      151  ...    1350    1351    1352    1352
# 161        9       32       83      128  ...    1272    1272    1272    1272
# 162       43       62      104      128  ...    1213    1215    1215    1215
# 163       24       43       69      100  ...    1018    1018    1018    1018
#
#      3/8/20  3/9/20  3/10/20  3/11/20  3/12/20  3/13/20
# 156   67707   67743    67760    67773    67781    67786
# 160    1352    1352     1353     1356     1356     1356
# 161    1272    1272     1272     1273     1273     1273
# 162    1215    1215     1215     1215     1215     1215
# 163    1018    1018     1018     1018     1018     1018
#
# [5 rows x 56 columns]

# %%
df_transposed = df_time_series_confirmed_china.T
df_transposed.head(10)
# Out:
#                     156        160      161       162      163      164  \
# Province/State    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui
# Country/Region    China      China    China     China    China    China
# Lat             30.9756    23.3417   33.882   29.1832  27.6104  31.8257
# Long            112.271    113.424  113.614   120.093  111.709  117.226
# 1/22/20             444         26        5        10        4        1
# 1/23/20             444         32        5        27        9        9
# 1/24/20             549         53        9        43       24       15
# 1/25/20             761         78       32        62       43       39
# 1/26/20            1058        111       83       104       69       60
# 1/27/20            1423        151      128       128      100       70
#
#                     165       166      168        169  ...      184  \
# Province/State  Jiangxi  Shandong  Jiangsu  Chongqing  ...    Gansu
# Country/Region    China     China    China      China  ...    China
# Lat              27.614   36.3427  32.9711    30.0572  ...  37.8099
# Long            115.722    118.15  119.455    107.874  ...  101.058
# 1/22/20               2         2        1          6  ...        0
# 1/23/20               7         6        5          9  ...        2
# 1/24/20              18        15        9         27  ...        2
# 1/25/20              18        27       18         57  ...        4
# 1/26/20              36        46       33         75  ...        7
# 1/27/20              72        75       47        110  ...       14
#
#                       185       186      187       189             190  \
# Province/State  Hong Kong  Liaoning    Jilin  Xinjiang  Inner Mongolia
# Country/Region      China     China    China     China           China
# Lat                  22.3   41.2956  43.6661   41.1129         44.0935
# Long                114.2   122.609  126.192   85.2401         113.945
# 1/22/20                 0         2        0         0               0
# 1/23/20                 2         3        1         2               0
# 1/24/20                 2         4        3         2               1
# 1/25/20                 5        17        4         3               7
# 1/26/20                 8        21        4         4               7
# 1/27/20                 8        27        6         5              11
#
#                     191      195      196      204
# Province/State  Ningxia  Qinghai    Macau    Tibet
# Country/Region    China    China    China    China
# Lat             37.2692  35.7452  22.1667  31.6927
# Long            106.165  95.9956   113.55  88.0924
# 1/22/20               1        0        1        0
# 1/23/20               1        0        2        0
# 1/24/20               2        0        2        0
# 1/25/20               3        1        2        0
# 1/26/20               4        1        5        0
# 1/27/20               7        6        6        0
#
# [10 rows x 33 columns]

# %%
df_transposed.reset_index(inplace = True) 
df_transposed.head()
# Out:
#             index      156        160      161       162      163      164  \
# 0  Province/State    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui
# 1  Country/Region    China      China    China     China    China    China
# 2             Lat  30.9756    23.3417   33.882   29.1832  27.6104  31.8257
# 3            Long  112.271    113.424  113.614   120.093  111.709  117.226
# 4         1/22/20      444         26        5        10        4        1
#
#        165       166      168  ...      184        185       186      187  \
# 0  Jiangxi  Shandong  Jiangsu  ...    Gansu  Hong Kong  Liaoning    Jilin
# 1    China     China    China  ...    China      China     China    China
# 2   27.614   36.3427  32.9711  ...  37.8099       22.3   41.2956  43.6661
# 3  115.722    118.15  119.455  ...  101.058      114.2   122.609  126.192
# 4        2         2        1  ...        0          0         2        0
#
#         189             190      191      195      196      204
# 0  Xinjiang  Inner Mongolia  Ningxia  Qinghai    Macau    Tibet
# 1     China           China    China    China    China    China
# 2   41.1129         44.0935  37.2692  35.7452  22.1667  31.6927
# 3   85.2401         113.945  106.165  95.9956   113.55  88.0924
# 4         0               0        1        0        1        0
#
# [5 rows x 34 columns]

# %%
df_transposed.columns = df_transposed.iloc[0]
df_transposed.head()
# Out:
# 0  Province/State    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui  \
# 0  Province/State    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui
# 1  Country/Region    China      China    China     China    China    China
# 2             Lat  30.9756    23.3417   33.882   29.1832  27.6104  31.8257
# 3            Long  112.271    113.424  113.614   120.093  111.709  117.226
# 4         1/22/20      444         26        5        10        4        1
#
# 0  Jiangxi  Shandong  Jiangsu  ...    Gansu  Hong Kong  Liaoning    Jilin  \
# 0  Jiangxi  Shandong  Jiangsu  ...    Gansu  Hong Kong  Liaoning    Jilin
# 1    China     China    China  ...    China      China     China    China
# 2   27.614   36.3427  32.9711  ...  37.8099       22.3   41.2956  43.6661
# 3  115.722    118.15  119.455  ...  101.058      114.2   122.609  126.192
# 4        2         2        1  ...        0          0         2        0
#
# 0  Xinjiang  Inner Mongolia  Ningxia  Qinghai    Macau    Tibet
# 0  Xinjiang  Inner Mongolia  Ningxia  Qinghai    Macau    Tibet
# 1     China           China    China    China    China    China
# 2   41.1129         44.0935  37.2692  35.7452  22.1667  31.6927
# 3   85.2401         113.945  106.165  95.9956   113.55  88.0924
# 4         0               0        1        0        1        0
#
# [5 rows x 34 columns]

# %%
df_transposed = df_transposed.rename(columns={'Province/State': 'Date'})

# %%
df_transposed.head()
# Out:
# 0            Date    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui  \
# 0  Province/State    Hubei  Guangdong    Henan  Zhejiang    Hunan    Anhui
# 1  Country/Region    China      China    China     China    China    China
# 2             Lat  30.9756    23.3417   33.882   29.1832  27.6104  31.8257
# 3            Long  112.271    113.424  113.614   120.093  111.709  117.226
# 4         1/22/20      444         26        5        10        4        1
#
# 0  Jiangxi  Shandong  Jiangsu  ...    Gansu  Hong Kong  Liaoning    Jilin  \
# 0  Jiangxi  Shandong  Jiangsu  ...    Gansu  Hong Kong  Liaoning    Jilin
# 1    China     China    China  ...    China      China     China    China
# 2   27.614   36.3427  32.9711  ...  37.8099       22.3   41.2956  43.6661
# 3  115.722    118.15  119.455  ...  101.058      114.2   122.609  126.192
# 4        2         2        1  ...        0          0         2        0
#
# 0  Xinjiang  Inner Mongolia  Ningxia  Qinghai    Macau    Tibet
# 0  Xinjiang  Inner Mongolia  Ningxia  Qinghai    Macau    Tibet
# 1     China           China    China    China    China    China
# 2   41.1129         44.0935  37.2692  35.7452  22.1667  31.6927
# 3   85.2401         113.945  106.165  95.9956   113.55  88.0924
# 4         0               0        1        0        1        0
#
# [5 rows x 34 columns]

# %%
df_transposed = df_transposed.drop([0,1,2,3])
df_transposed.head()
# Out:
# 0     Date Hubei Guangdong Henan Zhejiang Hunan Anhui Jiangxi Shandong  \
# 4  1/22/20   444        26     5       10     4     1       2        2
# 5  1/23/20   444        32     5       27     9     9       7        6
# 6  1/24/20   549        53     9       43    24    15      18       15
# 7  1/25/20   761        78    32       62    43    39      18       27
# 8  1/26/20  1058       111    83      104    69    60      36       46
#
# 0 Jiangsu  ... Gansu Hong Kong Liaoning Jilin Xinjiang Inner Mongolia Ningxia  \
# 4       1  ...     0         0        2     0        0              0       1
# 5       5  ...     2         2        3     1        2              0       1
# 6       9  ...     2         2        4     3        2              1       2
# 7      18  ...     4         5       17     4        3              7       3
# 8      33  ...     7         8       21     4        4              7       4
#
# 0 Qinghai Macau Tibet
# 4       0     1     0
# 5       0     2     0
# 6       0     2     0
# 7       1     2     0
# 8       1     5     0
#
# [5 rows x 34 columns]

# %%
labels = ['Hubei']
fig = df_transposed.plot(x = 'Date', 
                   y=['Hubei'], 
                   title = f'Line Plot of COVID-19 Confirmed Cases in {labels}')
plt.legend(labels)
plt.ylabel('Number of Cases')
fig.get_figure().savefig("hubei_cases.png")

# %%
df_transposed.head(30)

# %%
list(df_transposed.index)

# %%
for col in df_transposed.columns: 
    print(col)

# %%
labels = ['Guangdong','Henan','Zhejiang','Hunan']
fig = df_transposed.plot('Date', 
                   y = labels, 
                   title = f'Line Plot of COVID-19 Confirmed Cases in {labels}')
plt.legend(labels)
plt.ylabel('Number of Cases')
fig.get_figure().savefig("four_cases.png")

# %%
labels = ['Hubei', 'Guangdong','Henan','Zhejiang','Hunan']
fig = df_transposed.plot('Date', 
                   y = labels, 
                   title = f'Line Plot of COVID-19 Confirmed Cases in {labels}')
plt.legend(labels)
plt.ylabel('Number of Cases')
fig.get_figure().savefig("five_cases.png")

# %% [markdown]
# # Old

# %%
df_single_day = pd.read_csv("csse_covid_19_data/csse_covid_19_daily_reports/03-13-2020.csv")

# %%
df_single_day.head()

# %%
# df.count()

# %%
df_time_series_confirmed_china.set_index(['Province/State', 'Country/Region']).head()
